# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sale=pd.read_excel(r"C:\Users\hp\Desktop\projectfiles\project9_sales\Sales-Data-Analysis.xlsx")

# %%
sale
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 250         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 251         NaN      10710  2022-12-29 00:00:00             Burgers
# 252         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 253         NaN      10712  2022-12-29 00:00:00               Fries
# 254         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# ...

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %%
sale.drop(columns='Unnamed: 0',inplace=True)

# %%
sale
# Out:
#     Unnamed: 1           Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0     Order ID                 Date             Product      Price
# 1        10452  2022-11-07 00:00:00               Fries       3.49
# 2        10453  2022-11-07 00:00:00           Beverages       2.95
# 3        10454  2022-11-07 00:00:00       Sides & Other       4.99
# 4        10455  2022-11-08 00:00:00             Burgers      12.99
# ..         ...                  ...                 ...        ...
# 250      10709  2022-12-28 00:00:00       Sides & Other       4.99
# 251      10710  2022-12-29 00:00:00             Burgers      12.99
# 252      10711  2022-12-29 00:00:00  Chicken Sandwiches       9.95
# 253      10712  2022-12-29 00:00:00               Fries       3.49
# 254      10713  2022-12-29 00:00:00           Beverages       2.95
#
#      Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0      Quantity  Purchase Type  Payment Method             Manager       City
# ...

# %%
sale.columns=sale.loc[0]

# %%
sale.head()
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 0  Order ID                 Date        Product  Price    Quantity
# 1     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 2     10453  2022-11-07 00:00:00      Beverages   2.95  745.762712
# 3     10454  2022-11-07 00:00:00  Sides & Other   4.99  200.400802
# 4     10455  2022-11-08 00:00:00        Burgers  12.99  569.668976
#
# 0  Purchase Type  Payment Method             Manager    City
# 0  Purchase Type  Payment Method             Manager    City
# 1        Online        Gift Card    Tom      Jackson  London
# 2        Online        Gift Card         Pablo Perez  Madrid
# 3      In-store        Gift Card       Joao    Silva  Lisbon
# 4      In-store      Credit Card       Walter Muller  Berlin

# %%
sale.drop(0,inplace=True)

# %%
sale.head()
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method             Manager    City
# 1       Online       Gift Card    Tom      Jackson  London
# 2       Online       Gift Card         Pablo Perez  Madrid
# 3     In-store       Gift Card       Joao    Silva  Lisbon
# 4     In-store     Credit Card       Walter Muller  Berlin
# 5     In-store     Credit Card       Walter Muller  Berlin

# %% [markdown]
# # Consider the Manager column

# %%
sale.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
sale.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
len(sale.Manager.unique())
# Out:
# 14

# %%
sale['Manager'] = sale['Manager'].str.strip().str.replace(r'\s+', ' ', regex=True)   # to remove extra spaces in names

# %%
sale.Manager
# Out:
# 1        Tom Jackson
# 2        Pablo Perez
# 3         Joao Silva
# 4      Walter Muller
# 5      Walter Muller
#            ...
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# 254    Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
len(sale.Manager.unique())
# Out:
# 5

# %%
sale.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %% [markdown]
# # Removing the duplicate records

# %%
sale.describe()                            # to show some summary about the columns
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24736\1836918900.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   sale.describe()                            # to show some summary about the columns
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# ...

# %%
sale[sale.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %% [markdown]
# # Converting the datatype of columns

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
sale.Quantity = sale.Quantity.astype(float)

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 18.0+ KB

# %%
sale.Quantity = sale.Quantity.round()

# %%
sale.Quantity = sale.Quantity.astype(int)             # to change the datatype of a column

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 18.0+ KB

# %%
sale['Order ID'] = sale['Order ID'].astype(int)        # to change the datatype of a column
sale['Price'] = sale['Price'].astype(float)

# %%
sale.Date = pd.to_datetime(sale.Date)

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 18.0+ KB

# %% [markdown]
# # Analyzing the Data
# Q.1) Most Preferred Payment Method ?

# %%
sale['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
sale['Payment Method'].nunique()
# Out:
# 3

# %%
sale['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
sale['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
sale['Payment Method'].value_counts().plot(kind='bar') ;   # to draw the bar graph

# %% [markdown]
# # Q.2) Most Selling Product ?¶
# By Quantity
# By Revenue

# %% [markdown]
# # By Quantity

# %%
most_quantity = sale.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
most_quantity = most_quantity.reset_index()     # To convert the index of a Series into a column to form a DataFrame
most_quantity
# Out:
#               Product  Quantity
# 0           Beverages     34988
# 1               Fries     32023
# 2             Burgers     29018
# 3  Chicken Sandwiches     11133
# 4       Sides & Other      9800

# %%
plt.figure(figsize = (9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'], color = ['red', 'black', 'green', 'yellow', 'cyan'], width=0.4)
plt.title("Most Selling Product - By Quantity")              
plt.xlabel("Product")
plt.ylabel("Quantity");

# %% [markdown]
# # By Revenue

# %%
sale['Revenue'] = sale['Price'] * sale['Quantity']

# %%
sale
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# ...

# %%
most_revenue = sale.groupby('Product')['Revenue'].sum().sort_values(ascending = False)
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = most_revenue.reset_index()         # To convert the index of a Series into a column to form a DataFrame
most_revenue
# Out:
#               Product    Revenue
# 0             Burgers  376943.82
# 1               Fries  125626.57
# 2  Chicken Sandwiches  114612.45
# 3           Beverages  103214.60
# 4       Sides & Other   48902.00

# %%
plt.figure(figsize=(9, 4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'], color = ['green', 'red', 'black', 'yellow', 'cyan'], width = 0.3);
plt.title("Most Selling Product - By Revenue")       # setting the title       
plt.xlabel("Product")                                # setting the x-axis label
plt.ylabel("Revenue");                               # setting the y-axis label

# %% [markdown]
# # Q.3) Which city had maximum revenue¶
# or
# Which Manager earned maximum revenue

# %%
sale.groupby('City')['Revenue'].sum().sort_values(ascending=False)   # using groupby on 'City' & 'Revenue' column
# Out:
# City
# Lisbon    241635.49
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %%
sale.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)   # using groupby on 'Manager' & 'Revenue' column
# Out:
# Manager
# Joao Silva       241635.49
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# # Q.4) Date wise revenue

# %%
sale.plot('Date', 'Revenue', color='red', linewidth=2, figsize=(9,4)) 
plt.title("Date wise Revenue")                        # setting the title
plt.xlabel("Date")                                    # setting the x-axis label
plt.ylabel("Revenue")                                 # setting the y-axis label
plt.show()

# %% [markdown]
# # Q.5) Average Revenue

# %%
sale['Revenue'].mean()
# Out:
# np.float64(3028.737952755905)

# %% [markdown]
# # Q.6) Average Revenue of November & December month

# %%
sale['Month'] = sale['Date'].dt.month

# %%
sale
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11 = sale[sale['Month'] == 11]          # filtering the records with month '11'
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 109     10568 2022-11-30           Beverages   2.95       678       Online
# 110     10569 2022-11-30       Sides & Other   4.99       200       Online
# 128     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129     10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
float(m11.Revenue.mean())
# Out:
# 2938.1869026548666

# %%
m12 = sale[sale.Month == 12]                  # filtering the records with month '12'
m12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111     10570 2022-12-01             Burgers  12.99       493       Online
# 112     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113     10572 2022-12-01               Fries   3.49       573       Online
# 114     10573 2022-12-01           Beverages   2.95       678       Online
# 115     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
float(m12.Revenue.mean())
# Out:
# 3101.3072340425533

# %% [markdown]
# # Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
sale.groupby('Product')[['Quantity', 'Revenue']].agg({'Quantity':'mean', 'Revenue':'mean'})  # using agg() with groupby()
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           699.760000  2064.292000
# Burgers             558.038462  7248.919615
# Chicken Sandwiches  214.096154  2204.085577
# Fries               627.901961  2463.266078
# Sides & Other       200.000000   998.000000
